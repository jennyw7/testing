# %%
import sys
import os


sys.path.append(r"/Users/jenny.wang2/Data/GitHub/analytics-reporting/Python Scripts/SA QueryBuilder/src")

from Common_Functions import RS_Adv_conn_func
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       2 import os
#       5 sys.path.append(r"/Users/jenny.wang2/Data/GitHub/analytics-reporting/Python Scripts/SA QueryBuilder/src")
# ----> 7 from Common_Functions import RS_Adv_conn_func
#
# File ~/Data/GitHub/analytics-reporting/Python Scripts/SA QueryBuilder/src/Common_Functions.py:17
#      14 # Loading Libraries
#      16 import pandas as pd
# ---> 17 import sqlalchemy as sa
#      18 from sqlalchemy.engine.url import URL
#      19 from snowflake.sqlalchemy import URL as sURL
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
import pandas as pd

# %%
# Create DataFrame from a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
